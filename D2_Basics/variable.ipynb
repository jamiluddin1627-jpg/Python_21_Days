# %% [markdown]
# Correct Variables Name

# %%
name = "Jamil";
print(name)
# Out:
# Jamil

# %%
x = 10 
y = 20
z = x + y
print(z)
# Out:
# 30

# %%
student_name = "Alice"
student_age = 20
student_grade = 85
print("Student Name:", student_name)
print("Student Age:", student_age)
print("Student Grade:", student_grade)
# Out:
# Student Name: Alice
# Student Age: 20
# Student Grade: 85

# %%
_x = 5
_y = 10
_z = _x + _y
print(_z)
# Out:
# 15

# %%
a1 = 15
b2 = 25
c2 = a1 + b2
print(c2)
# Out:
# 40

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Variable assigning

# %%
a = 10 # Initialize variable a with value 10
b = 20 # Initialize variable b with value 20
c = a + b # Initialize variable c with the sum of a and b
print(c) # Print the value of variable c
# Out:
# 30

# %%
a = 10
b = 10
c = 10
a = b = c = 10
print(a, b, c)
# Out:
# 10 10 10

# %%
name, age, grade = "Jamil", 26, 3.90
print(name, age, grade)
# Out:
# Jamil 26 3.9
